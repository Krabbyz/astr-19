# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
nums = np.random.normal(loc=0, scale=1.0, size=1000)
plt.hist(nums, bins=100, alpha=0.5, edgecolor="black")
plt.xlabel('value')
plt.ylabel('frequency')
plt.show()

plt.savefig("plots.pdf")
